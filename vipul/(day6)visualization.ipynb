# %%
import matplotlib.pyplot as plt
import numpy as np
xpoints=np.array([0,4,5,8])
ypoints=np.array([1,5,6,7])
plt.plot(xpoints,ypoints)
#plt.plot(ypoints,'0',ms=20,mec='r',mfc='g')
#plt.plot(ypoints,ls='--',color='k')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
#xpoints=np.array([0,4,5,8])
ypoints=np.array([1,5,6,7])
#plt.plot(xpoints,ypoints)
#plt.plot(ypoints,'0',ms=20,mec='r',mfc='g')
plt.plot(ypoints,ls='--',color='k')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
xpoints=np.array([0,4,5,8])
ypoints=np.array([1,5,6,7])
plt.plot(xpoints,ypoints)
plt.plot(ypoints,'1',ms=20,mec='r',mfc='g')
#plt.plot(ypoints,ls='--',color='k')
plt.show()

# %%
#label 
import matplotlib.pyplot as plt
import numpy as np
xpoints=np.array([0,4,5,8])
ypoints=np.array([1,5,6,7])
plt.plot(xpoints,ypoints)
plt.plot(ypoints,'1',ms=20,mec='r',mfc='g')
#plt.plot(ypoints,ls='--',color='k')
plt.title("avrage")
plt.xlabel('speed')
plt.ylabel('distance')
plt.grid()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
x=np.array([0,4,5,8])
y=np.array([1,5,6,7])
plt.scatter(x,y)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
xpoints=np.array([70,80,90])
ypoints=np.array([100,400,600])
plt.bar(xpoints,ypoints)
plt.title("avrage")
plt.xlabel('speed')
plt.ylabel('distance')
#plt.grid()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
xpoints=np.array([70,80,90])
ypoints=np.array([100,400,600])
mycolors = ["black", "hotpink", "green"]
plt.pie(xpoints, colors =mycolors)
plt.pie(ypoints,colors =mycolors)
plt.title("avrage")
plt.xlabel('speed')
plt.ylabel('distance')
#plt.grid()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
x=np.array([70,80,90])
y=np.array([100,400,600])
plt.hist(x,bin =13, color ="green",edgecolor="blue")
plt.title("avrage")
plt.xlabel('speed')
plt.ylabel('distance')
#plt.grid()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_4212\2201895537.py in <module>
#       3 x=np.array([70,80,90])
#       4 y=np.array([100,400,600])
# ----> 5 plt.hist(x,bin =13, color ="green",edgecolor="blue")
#       6 plt.title("avrage")
#       7 plt.xlabel('speed')
#
# ~\Anaconda3\lib\site-packages\matplotlib\pyplot.py in hist(x, bins, range, density, weights, cumulative, bottom, histtype, align, orientation, rwidth, log, color, label, stacked, data, **kwargs)
#    2600         orientation='vertical', rwidth=None, log=False, color=None,
#    2601         label=None, stacked=False, *, data=None, **kwargs):
# -> 2602     return gca().hist(
#    2603         x, bins=bins, range=range, density=density, weights=weights,
#    2604         cumulative=cumulative, bottom=bottom, histtype=histtype,
#
# ...

# %% [markdown]
# """creat a numpy array x containingh data representing type time(hrs) spent on studying:(1,2,3,4,5,)
# ceate a numpy arry y containingh corresponding data representing study courese (out of 100):[50,60,70,80,90]
# plot a line grapgh with blue solid line
# overlay a scatter plote with red markers
#
# part two
#
# creat a numpy asrry categareis representing diffrent subjects:[maths , sci , hist, art]
# creat a numpy arry score out of 100 for each subject : [85,70,75,90,80]
# plot a bar gharph representing subject and its scores
# clour each bar diffretly
# add label title and modifiy the grid lines to disply --- style """

# %%
import matplotlib.pyplot as plt
import numpy as np
time=(1,2,3,4,5)
y=np.array([50,60,70,80,90])
plt.plot(time,y,color='#0000FF')
plt.scatter(time,y ,color = 'Red')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
subject=np.array(['math' , 'sci' , 'hist', 'eng', 'art'])
out=np.array([85,70,75,90,80])  
plt.bar(subject,out, color=["black", "hotpink", "green","blue","red"])
plt.title("avrage")
plt.xlabel('subject')
plt.ylabel('score')
plt.grid()
plt.show()
